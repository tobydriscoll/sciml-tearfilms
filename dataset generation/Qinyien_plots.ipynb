# %%
import h5py
import numpy as np
from scipy.integrate import solve_ivp
from scipy.stats.qmc import Halton
from time import time
import torch
import matplotlib.pyplot as plt
from joblib import Parallel, delayed  # For parallel execution

# %%
old_file_path = "C:/Users/arnab/OneDrive/Desktop/Study material/summer 24/Research/Old equations/datasets/all_data_1d_glob.jld2"
new_file_path = "C:/Users/arnab/OneDrive/Desktop/Study material/summer 24/Research/New equations/datasets/all_data_1d_glob.jld2"

# %%
datastore = h5py.File(new_file_path, 'r')
datastore.keys()
# Out:
# <KeysViewHDF5 ['data_I', 'data_c', 'data_h', 'para3']>

# %%
data_I = np.array(datastore["data_I"])
data_h = np.array(datastore["data_h"])
data_c = np.array(datastore["data_c"])

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
# device = "cpu"
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
n = np.random.randint(0, len(data_h))
print(n)
plt.plot(data_h[n])
plt.show()
plt.plot(data_c[n])
plt.show()
plt.plot(data_I[n])
plt.show()
# Out:
# 13394

# %%
n = np.random.randint(0, len(data_h))
print(n)
plt.plot(data_h[n])
plt.show()
plt.plot(data_c[n])
plt.show()
plt.plot(data_I[n])
plt.show()
# Out:
# 4853

# %%
n = np.random.randint(0, len(data_h))
print(n)
plt.plot(data_h[n])
plt.show()
plt.plot(data_c[n])
plt.show()
plt.plot(data_I[n])
plt.show()
# Out:
# 6737

# %%
n = np.random.randint(0, len(data_h))
print(n)
plt.plot(data_h[n])
plt.show()
plt.plot(data_c[n])
plt.show()
plt.plot(data_I[n])
plt.show()
# Out:
# 8692
